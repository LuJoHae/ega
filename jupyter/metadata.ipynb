# %%
from pathlib import Path
import pandas as pd

# %%
dirpath = Path("/Users/halu/remote_connections/olm/storage/big-icir-datasets/EGAD00001003977/metadata")
assert dirpath.exists()

# %%
filepath = dirpath / "experiments.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# accession_id                     348
# design_description                 1
# library_name                       1
# library_construction_protocol      1
# paired_nominal_length              1
# paired_nominal_sdev                1
# platform                           1
# model                              1
# library_layout                     1
# library_strategy                   1
# library_source                     1
# library_selection                  1
# extra_attributes                   1
# study_accession_id                 1
# submission_accession_id            1
# created_at                         6
# edited_at                          6
# dtype: int64
#       accession_id             design_description library_name  \
# 0  EGAX00001607543  TruSeq RNA Exome (RNA access)           \N
# 1  EGAX00001607544  TruSeq RNA Exome (RNA access)           \N
# 2  EGAX00001607545  TruSeq RNA Exome (RNA access)           \N
# ...

# %%
filepath = dirpath / "run_sample.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# sample_alias               348
# sample_accession_id        348
# biosample_id               348
# run_accession_id           348
# experiment_accession_id    348
# study_accession_id           1
# sample_attributes          348
# dtype: int64
#       sample_alias sample_accession_id    biosample_id run_accession_id  \
# 0  SAM00b9e5c52da9     EGAN00001627928  SAMEA104453869  EGAR00001652884
# 1  SAM0257bbbbd388     EGAN00001627900  SAMEA104453841  EGAR00001652885
# 2  SAM025b45c27e05     EGAN00001627771  SAMEA104453712  EGAR00001652886
# 3  SAM032c642382a7     EGAN00001627721  SAMEA104453662  EGAR00001652887
# 4  SAM04c589eb3fb3     EGAN00001627992  SAMEA104453933  EGAR00001653159
#
#   experiment_accession_id study_accession_id  \
# 0         EGAX00001607543    EGAS00001002556
# 1         EGAX00001607544    EGAS00001002556
# 2         EGAX00001607545    EGAS00001002556
# 3         EGAX00001607546    EGAS00001002556
# 4         EGAX00001607818    EGAS00001002556
#
# ...

# %%
filepath = dirpath / "runs.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# accession_id               348
# run_file_type                1
# extra_attributes             1
# sample_accession_id        348
# experiment_accession_id    348
# submission_accession_id      1
# created_at                   5
# edited_at                    2
# dtype: int64
#       accession_id run_file_type extra_attributes sample_accession_id  \
# 0  EGAR00001652884         fastq               \N     EGAN00001627928
# 1  EGAR00001652885         fastq               \N     EGAN00001627900
# 2  EGAR00001652886         fastq               \N     EGAN00001627771
# 3  EGAR00001652887         fastq               \N     EGAN00001627721
# 4  EGAR00001652888         fastq               \N     EGAN00001627851
#
#   experiment_accession_id submission_accession_id              created_at  \
# 0         EGAX00001607543          EGA00001409650  2018-02-16 23:51:10+01
# 1         EGAX00001607544          EGA00001409650  2018-02-16 23:51:10+01
# ...

# %%
filepath = dirpath / "sample_file.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# sample_accession_id    348
# sample_alias           348
# file_name              696
# file_accession_id      696
# dtype: int64
#   sample_accession_id     sample_alias  \
# 0     EGAN00001627665  SAMf2ce197162ce
# 1     EGAN00001627665  SAMf2ce197162ce
# 2     EGAN00001627666  SAM698d8d76b934
# 3     EGAN00001627666  SAM698d8d76b934
# 4     EGAN00001627667  SAMc1b27bc16435
#
#                                            file_name file_accession_id
# 0  GO29293_RNAseq_GO29293_ngs_rna_targrna_rnaacce...   EGAF00001873319
# 1  GO29293_RNAseq_GO29293_ngs_rna_targrna_rnaacce...   EGAF00001873320
# 2  GO29293_RNAseq_GO29293_ngs_rna_targrna_rnaacce...   EGAF00001873573
# 3  GO29293_RNAseq_GO29293_ngs_rna_targrna_rnaacce...   EGAF00001873574
# 4  GO29293_RNAseq_GO29293_ngs_rna_targrna_rnaacce...   EGAF00001873115

# %%
filepath = dirpath / "samples.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# accession_id               348
# alias                      348
# title                      347
# description                347
# biological_sex               2
# subject_id                 347
# phenotype                    1
# extra_attributes           348
# submission_accession_id      1
# created_at                  17
# edited_at                    1
# dtype: int64
#       accession_id            alias              title  \
# 0  EGAN00001627665  SAMf2ce197162ce  tumor RNA (10255)
# 1  EGAN00001627666  SAM698d8d76b934  tumor RNA (10101)
# 2  EGAN00001627667  SAMc1b27bc16435  tumor RNA (10230)
# 3  EGAN00001627668  SAM85e41e7f33f9  tumor RNA (10264)
# 4  EGAN00001627669  SAMf275eb859a39  tumor RNA (10150)
#
#                                  description biological_sex  subject_id  \
# 0  RNA extracted from tumor of patient 10255           male       10255
# 1  RNA extracted from tumor of patient 10101         female       10101
# ...

# %%
filepath = dirpath / "study_experiment_run_sample.tsv"
assert filepath.exists()
df = pd.read_csv(filepath , sep="\t")
print(df.nunique())
df.head()
# Out:
# study_accession_id           1
# study_title                  1
# study_type                   1
# instrument_platform          1
# instrument_model             1
# library_layout               1
# library_name                 1
# library_strategy             1
# library_source               1
# library_selection            1
# experiment_accession_id    348
# run_accession_id           348
# sample_accession_id        348
# sample_alias               348
# biosample_id               348
# sample_title               347
# dtype: int64
#   study_accession_id                                        study_title  \
# 0    EGAS00001002556  TGF-β attenuates tumour response to PD-L1 bloc...
# 1    EGAS00001002556  TGF-β attenuates tumour response to PD-L1 bloc...
# 2    EGAS00001002556  TGF-β attenuates tumour response to PD-L1 bloc...
# 3    EGAS00001002556  TGF-β attenuates tumour response to PD-L1 bloc...
# 4    EGAS00001002556  TGF-β attenuates tumour response to PD-L1 bloc...
#
# ...
